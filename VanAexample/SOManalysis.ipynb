# %% [markdown]
# # Importing and loading

# %% [markdown]
# ## Python imports

# %%
import SOM2
import SOMTools
import SOMclust
import scipy
import IO
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session

# %% [markdown]
# ## Importing SOM data

# %%
smap = load('smap.npy')

# %%
inputmat = load('projections.npy')
som = SOM2.SOM(inputmat)
som.smap = smap

# %% [markdown]
# ## Importing trajectory (only C-alpha trace)

# %%
# %time traj = IO.Trajectory('VanA-VanAss.dcd', struct='1E4E-prot-CA.pdb')
# Out:
# CPU times: user 26.43 s, sys: 0.65 s, total: 27.08 s
# Wall time: 48.17 s

# %% [markdown]
# ## Computing the Best Matching Units: which structures are in each cells of the map

# %%
# %time bmus = som.get_allbmus()
save('bmus', bmus)

# %%
bmus = load('bmus.npy')

# %% [markdown]
# # Computing the density

# %%
X,Y,Z = smap.shape
density = zeros((X,Y), dtype=int)
for i,j in bmus:
    density[i,j]+=1
matshow(density)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa631b0c>

# %% [markdown]
# # Computing U-matrix

# %%
umat = SOMTools.getUmatrix(smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa7c22ec>

# %% [markdown]
# # Computing clusters from the U-matrix

# %% [markdown]
# ## Flooding of the U-matrix

# %%
clust = SOMclust.clusters(umat, bmus, smap)
# Out:
# 0.96/100: flooding: 24/2499, 1624.49, (129, 145)
# 1.92/100: flooding: 48/2499, 1817.78, (127, 155)
# 2.88/100: flooding: 72/2499, 1829.97, (133, 148)
# 3.84/100: flooding: 96/2499, 1902.53, (134, 146)
# 4.80/100: flooding: 120/2499, 1949.30, (132, 145)
# 5.76/100: flooding: 144/2499, 2037.26, (129, 155)
# 6.72/100: flooding: 168/2499, 2120.26, (142, 146)
# 7.68/100: flooding: 192/2499, 2235.66, (142, 147)
# 8.64/100: flooding: 216/2499, 2379.26, (134, 153)
# 9.60/100: flooding: 240/2499, 2495.28, (140, 149)
# 10.56/100: flooding: 264/2499, 2189.05, (115, 149)
# 11.52/100: flooding: 288/2499, 2431.97, (118, 151)
# 12.48/100: flooding: 312/2499, 2602.55, (136, 155)
# 13.45/100: flooding: 336/2499, 2493.25, (117, 157)
# 14.41/100: flooding: 360/2499, 2626.97, (135, 142)
# 15.37/100: flooding: 384/2499, 2666.02, (112, 153)
# 16.33/100: flooding: 408/2499, 2708.71, (133, 157)
# 17.29/100: flooding: 432/2499, 2754.08, (139, 152)
# 18.25/100: flooding: 456/2499, 2818.95, (111, 151)
# 19.21/100: flooding: 480/2499, 2874.23, (142, 150)
# 20.17/100: flooding: 504/2499, 2956.22, (116, 152)
# 21.13/100: flooding: 528/2499, 3011.84, (138, 155)
# 22.09/100: flooding: 552/2499, 3131.93, (113, 148)
# 23.05/100: flooding: 576/2499, 3206.41, (141, 153)
# 24.01/100: flooding: 600/2499, 3291.48, (116, 166)
# 24.97/100: flooding: 624/2499, 3427.37, (115, 161)
# 25.93/100: flooding: 648/2499, 1555.44, (127, 134)
# 72.03/100: flooding: 1800/2499, 4359.08, (107, 147)
# 72.99/100: flooding: 1824/2499, 4568.06, (105, 148)
# 73.95/100: flooding: 1848/2499, 3809.49, (145, 161)
# 74.91/100: flooding: 1872/2499, 3888.77, (146, 165)
# 75.87/100: flooding: 1896/2499, 3088.06, (146, 171)
# 76.83/100: flooding: 1920/2499, 3155.85, (149, 174)
# 77.79/100: flooding: 1944/2499, 3489.84, (146, 169)
# 78.75/100: flooding: 1968/2499, 3666.97, (155, 166)
# 79.71/100: flooding: 1992/2499, 3927.10, (148, 176)
# 80.67/100: flooding: 2016/2499, 4031.25, (148, 166)
# 81.63/100: flooding: 2040/2499, 4186.35, (148, 158)
# 82.59/100: flooding: 2064/2499, 4340.01, (150, 162)
# 83.55/100: flooding: 2088/2499, 4460.07, (155, 162)
# 84.51/100: flooding: 2112/2499, 4599.00, (140, 164)
# 85.47/100: flooding: 2136/2499, 4775.43, (140, 158)
# 86.43/100: flooding: 2160/2499, 4881.25, (91, 130)
# 87.39/100: flooding: 2184/2499, 5067.53, (133, 119)
# 88.36/100: flooding: 2208/2499, 5195.51, (146, 178)
# 89.32/100: flooding: 2232/2499, 5372.24, (156, 161)
# 90.28/100: flooding: 2256/2499, 5653.81, (99, 131)
# 91.24/100: flooding: 2280/2499, 5939.76, (90, 129)
# 92.20/100: flooding: 2304/2499, 6378.55, (148, 155)
# 93.16/100: flooding: 2328/2499, 6959.92, (109, 158)
# 94.12/100: flooding: 2352/2499, 7433.99, (97, 131)
# 95.08/100: flooding: 2376/2499, 7854.67, (91, 129)
# 96.04/100: flooding: 2400/2499, 8613.47, (152, 175)
# 97.00/100: flooding: 2424/2499, 9307.85, (140, 176)
# 97.96/100: flooding: 2448/2499, 9886.44, (104, 155)
# 98.92/100: flooding: 2472/2499, 10470.69, (86, 124)
# 99.88/100: flooding: 2496/2499, 11846.01, (156, 157)

# %%
imshow(ma.masked_array(clust.umat_cont, clust.mask), interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa993a4c>

# %% [markdown]
# ## Computing clusters

# %%
clust.getclusters()
# Out:
# /usr/lib/pymodules/python2.7/numpy/ma/core.py:3785: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# (array([[20, 20, 20, ..., 18, 18, 18],
#        [20, 20, 20, ..., 24, 24, 24],
#        [20, 20, 20, ..., 24, 24, 24],
#        ...,
#        [ 5,  5,  5, ...,  7,  6,  6],
#        [30, 30, 30, ...,  7,  7,  6],
#        [12, 12,  9, ...,  7,  7,  6]]),
#  array([[20, 20, 20, ...,  0,  0,  0],
#        [20, 20, 20, ...,  0,  0,  0],
#        [20, 20, 20, ..., 24, 24, 24],
#        ...,
#        [ 0,  0,  0, ...,  0,  0,  6],
#        [ 0,  0,  0, ...,  7,  0,  0],
#        [ 0,  0,  0, ...,  7,  0,  0]]))

# %%
clust.plotclusters()
#savefig('umat_VanA.png', dpi=300)

# %% [markdown]
# ## Which structures are in each clusters?

# %%
nframes = clust.labels.size
clusters = []
for i in range(nframes):
    clusters.append([i, clust.labels[i]])
clusters = asarray(clusters)
clusters = clusters[clusters[:,1].argsort()]
savetxt('clusters', clusters, fmt='%d')

# %% [markdown]
# # Projecting data onto the SOM

# %% [markdown]
# ## The RMSD

# %% [markdown]
# ### Structural alignment

# %%
traj.struct.atoms['coord'] = traj.struct.atoms['coord'] - traj.struct.atoms['coord'].mean(axis=0)

# %%
traj.align(templatestruct=(traj.struct.atoms['coord']).flatten())

# %%
i,j = traj.array.shape
print (i,j)

# %%
traj.array = traj.array.reshape((i, j/3, 3))
traj.array.shape

# %% [markdown]
# ### Computing the RMSD

# %%
rmsds = sqrt((( traj.array - traj.struct.atoms['coord']*numpy.ones_like(traj.array) )**2).sum(axis=2)).mean(axis=1)

# %%
histo = hist(rmsds, 100, range=[0,5])

# %% [markdown]
# ### Projecting the RMSD onto the SOM

# %%
def project(data):
    pmap = zeros((X,Y))
    for c,e in enumerate(bmus):
        i,j = e
        pmap[i,j]+=data[c]
    pmap = pmap / density
    pmap = clust.flood(pmap, clust.x_offset, clust.y_offset, clust.mask)[0]
    return pmap

# %%
rmsdmap = project(rmsds)

# %%
clust.plotclusters(color='k', matrix=rmsdmap, cmap=cm.PRGn, vmax=3.)
savefig('rmsdmap_VanA.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c809781dd632> in <module>()
# ----> 1 clust.plotclusters(color='k', matrix=rmsdmap, cmap=cm.PRGn, vmax=3.)
#       2 savefig('rmsdmap_VanA.png', dpi=300)
#
# NameError: name 'clust' is not defined

# %%
mu_rmsd = []
std_rmsd = []
clustid = unique(clust.labels)
for e in clustid:
    clustrmsd = rmsds[nonzero(clust.labels == e)[0]]
    mu = clustrmsd.mean()
    mu_rmsd.append(mu)
    std = clustrmsd.std()
    std_rmsd.append(std)
    text(e, mu+std, clustrmsd.size, horizontalalignment='center')
bar(clustid, mu_rmsd, yerr=std_rmsd, align='center')
ylabel("rmsd in A")
xlabel("cluster id")
grid()

# %% [markdown]
# ### Saving clusters

# %%
for e in unique(clusters[:,1]):
    save('clust_%d'%e, traj.array[clusters[:,0][clusters[:,1] == e]])

# %% [markdown]
# ### Gyration radius

# %%
def getgyrationradius(frame):
    frame = frame - frame.mean(axis=0)
    m = dot(frame.T,frame)
    eigval, eigvect = linalg.eig(m)
    eigvect = eigvect[:,eigval.argsort()[::-1]]
    eigval = eigval[eigval.argsort()[::-1]]
    return eigval[1]/eigval[0]
getgyrationradius(traj.array[1000])

# %%
g_radius = asarray(map(getgyrationradius, traj.array))

# %%
histo = hist(g_radius, 100)

# %%
g_radius_map = project(g_radius)

# %%
clust.plotclusters(color='k', matrix=g_radius_map, cmap=cm.PRGn)

# %% [markdown]
# ### MMGBSA energies

# %%
egb = genfromtxt('EGB-Total-VanA_VanAss-1col.dat')

# %%
egb_map = project(egb)
# Out:
# -c:6: RuntimeWarning: invalid value encountered in divide

# %%
histo = hist(egb, 100)

# %%
clust.plotclusters(color='k', matrix=SOMTools.ddmap(egb_map), cmap=cm.PRGn, interpolation='nearest')
savefig('../figures/egbmap.png', dpi=300)
