# %% [markdown]
# # Importing and loading

# %% [markdown]
# ## Python imports

# %%
import SOM2
import SOMTools
import SOMclust
import scipy
import IO
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session

# %% [markdown]
# ## Importing SOM data

# %%
smap = load('smap.npy')

# %%
inputmat = load('projections.npy')
som = SOM2.SOM(inputmat)
som.smap = smap

# %% [markdown]
# ## Importing trajectory (only C-alpha trace)

# %%
traj = IO.Trajectory('newtraj78_210521_ca.dcd', struct='2pgb_hydro_ca.pdb')

# %% [markdown]
# ## Computing the Best Matching Units: which structures are in each cells of the map

# %%
bmus = som.get_allbmus()

# %% [markdown]
# # Computing the density

# %%
X,Y,Z = smap.shape
density = zeros((X,Y), dtype=int)
for i,j in bmus:
    density[i,j]+=1
matshow(density)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2113c488>

# %% [markdown]
# # Computing U-matrix

# %%
umat = SOMTools.getUmatrix(smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x214877a0>

# %% [markdown]
# # Computing clusters from the U-matrix

# %% [markdown]
# ## Flooding of the U-matrix

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, smap)
# Out:
# 0.96/100: flooding: 24/2499, 125.61, (144, 123)
# 1.92/100: flooding: 48/2499, 135.40, (142, 114)
# 2.88/100: flooding: 72/2499, 119.60, (134, 107)
# 3.84/100: flooding: 96/2499, 127.09, (130, 111)
# 4.80/100: flooding: 120/2499, 135.86, (134, 106)
# 5.76/100: flooding: 144/2499, 140.79, (141, 127)
# 6.72/100: flooding: 168/2499, 146.18, (138, 120)
# 7.68/100: flooding: 192/2499, 150.50, (138, 119)
# 8.64/100: flooding: 216/2499, 154.69, (126, 107)
# 9.60/100: flooding: 240/2499, 133.81, (121, 118)
# 10.56/100: flooding: 264/2499, 157.98, (124, 120)
# 11.52/100: flooding: 288/2499, 161.63, (144, 111)
# 12.48/100: flooding: 312/2499, 165.88, (138, 117)
# 13.45/100: flooding: 336/2499, 170.21, (137, 115)
# 14.41/100: flooding: 360/2499, 174.69, (141, 129)
# 15.37/100: flooding: 384/2499, 166.51, (152, 117)
# 16.33/100: flooding: 408/2499, 181.23, (124, 119)
# 17.29/100: flooding: 432/2499, 185.21, (150, 118)
# 18.25/100: flooding: 456/2499, 191.55, (149, 113)
# 19.21/100: flooding: 480/2499, 198.22, (135, 120)
# 20.17/100: flooding: 504/2499, 204.36, (147, 104)
# 21.13/100: flooding: 528/2499, 209.32, (119, 117)
# 22.09/100: flooding: 552/2499, 215.41, (119, 114)
# 23.05/100: flooding: 576/2499, 222.12, (122, 122)
# 24.01/100: flooding: 600/2499, 227.52, (134, 122)
# 24.97/100: flooding: 624/2499, 232.39, (135, 130)
# 25.93/100: flooding: 648/2499, 227.11, (154, 111)
# 26.89/100: flooding: 672/2499, 165.78, (112, 118)
# 27.85/100: flooding: 696/2499, 180.06, (116, 122)
# 28.81/100: flooding: 720/2499, 198.91, (119, 125)
# 29.77/100: flooding: 744/2499, 213.43, (111, 114)
# 30.73/100: flooding: 768/2499, 236.47, (109, 114)
# 31.69/100: flooding: 792/2499, 245.95, (135, 103)
# 32.65/100: flooding: 816/2499, 251.79, (131, 123)
# 33.61/100: flooding: 840/2499, 245.21, (134, 100)
# 34.57/100: flooding: 864/2499, 259.03, (149, 104)
# 35.53/100: flooding: 888/2499, 262.46, (154, 115)
# 36.49/100: flooding: 912/2499, 267.74, (127, 103)
# 37.45/100: flooding: 936/2499, 271.54, (137, 102)
# 38.42/100: flooding: 960/2499, 276.01, (119, 111)
# 93.16/100: flooding: 2328/2499, 2608.73, (105, 104)
# 94.12/100: flooding: 2352/2499, 2712.65, (161, 79)
# 95.08/100: flooding: 2376/2499, 2822.39, (105, 93)
# 96.04/100: flooding: 2400/2499, 2861.42, (164, 87)
# 97.00/100: flooding: 2424/2499, 2976.39, (104, 99)
# 97.96/100: flooding: 2448/2499, 3077.19, (113, 132)
# 98.92/100: flooding: 2472/2499, 3393.10, (118, 141)
# 99.88/100: flooding: 2496/2499, 4047.64, (119, 139)

# %%
imshow(ma.masked_array(clust.umat_cont, clust.mask), interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x21ecfd88>

# %% [markdown]
# ## Computing clusters

# %%
clust.getclusters()
# Out:
# /c5/shared/Python/2.7.4-shared/lib/python2.7/site-packages/numpy/ma/core.py:3785: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# (array([[20,  6,  6, ...,  7,  7,  7],
#        [20,  6,  6, ...,  7,  7,  7],
#        [20,  6,  6, ...,  7,  7,  7],
#        ...,
#        [ 9,  9,  9, ...,  7,  7,  7],
#        [ 9,  9,  9, ...,  7,  7,  7],
#        [ 9,  9,  9, ...,  7,  7,  7]]),
#  array([[0, 0, 6, ..., 0, 0, 0],
#        [0, 0, 6, ..., 7, 7, 7],
#        [0, 0, 6, ..., 7, 7, 7],
#        ...,
#        [9, 9, 9, ..., 7, 7, 7],
#        [9, 9, 9, ..., 7, 7, 7],
#        [9, 9, 9, ..., 7, 7, 7]]))

# %%
clust.plotclusters()

# %% [markdown]
# ## Which structures are in each clusters?

# %%
nframes = clust.labels.size
clusters = []
for i in range(nframes):
    clusters.append([i, clust.labels[i]])
clusters = asarray(clusters)
clusters = clusters[clusters[:,1].argsort()]
savetxt('clusters', clusters, fmt='%d')

# %% [markdown]
# # Projecting data onto the SOM

# %% [markdown]
# ## The RMSD

# %% [markdown]
# ### Structural alignment

# %%
traj.struct.atoms['coord'] = traj.struct.atoms['coord'] - traj.struct.atoms['coord'].mean(axis=0)

# %%
traj.align(templatestruct=(traj.struct.atoms['coord']).flatten())

# %%
i,j = traj.array.shape
print (i,j)
# Out:
# (9249, 168)

# %%
traj.array = traj.array.reshape((i, j/3, 3))
traj.array.shape
# Out:
# (9249, 56, 3)

# %% [markdown]
# ### Computing the RMSD

# %%
rmsds = sqrt((( traj.array - traj.struct.atoms['coord']*numpy.ones_like(traj.array) )**2).sum(axis=2)).mean(axis=1)

# %%
histo = hist(rmsds, 100, range=[0,5])

# %% [markdown]
# ### Projecting the RMSD onto the SOM

# %%
def project(data):
    pmap = zeros((X,Y))
    for c,e in enumerate(bmus):
        i,j = e
        pmap[i,j]+=data[c]
    pmap = pmap / density
    pmap = clust.flood(pmap, clust.x_offset, clust.y_offset, clust.mask)[0]
    return pmap
rmsdmap = project(rmsds)
# Out:
# -c:6: RuntimeWarning: invalid value encountered in divide

# %%
clust.plotclusters(color='k', matrix=rmsdmap, cmap=cm.PRGn, vmax=2.)

# %%
mu_rmsd = []
std_rmsd = []
clustid = unique(clust.labels)
for e in clustid:
    clustrmsd = rmsds[nonzero(clust.labels == e)[0]]
    mu = clustrmsd.mean()
    mu_rmsd.append(mu)
    std = clustrmsd.std()
    std_rmsd.append(std)
    text(e, mu+std, clustrmsd.size, horizontalalignment='center')
bar(clustid, mu_rmsd, yerr=std_rmsd, align='center')
ylabel("rmsd in A")
xlabel("cluster id")
grid()

# %% [markdown]
# ### Saving clusters

# %%
for e in unique(clusters[:,1]):
    save('clust_%d'%e, traj.array[clusters[:,0][clusters[:,1] == e]])
