# %% [markdown]
# # Importing and loading

# %% [markdown]
# ## Python imports

# %%
import SOM2
import SOMTools
import SOMclust
import scipy
import IO
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session

# %% [markdown]
# ## Importing SOM data

# %%
smap = load('smap.npy')

# %%
inputmat = load('projections.npy')
som = SOM2.SOM(inputmat)
som.smap = smap

# %% [markdown]
# ## Importing trajectory (only C-alpha trace)

# %%
traj = IO.Trajectory('newtraj78_210521_ca.dcd', struct='2pgb_hydro_ca.pdb')

# %% [markdown]
# ## Computing the Best Matching Units: which structures are in each cells of the map

# %%
bmus = som.get_allbmus()

# %%
bmus.shape
# Out:
# (9249, 2)

# %% [markdown]
# # Computing the density

# %%
X,Y,Z = smap.shape
density = zeros((X,Y), dtype=int)
for i,j in bmus:
    density[i,j]+=1
matshow(density)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb4f83fcc>

# %% [markdown]
# # Computing U-matrix

# %%
umat = SOMTools.getUmatrix(smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb2e6b2c>

# %% [markdown]
# # Computing clusters from the U-matrix

# %% [markdown]
# ## Flooding of the U-matrix

# %%
clust = SOMclust.clusters(umat, bmus, smap)
# Out:
# 0.96/100: flooding: 24/2499, 96.31, (118, 135)
# 1.92/100: flooding: 48/2499, 103.59, (120, 130)
# 2.88/100: flooding: 72/2499, 105.93, (126, 134)
# 3.84/100: flooding: 96/2499, 110.39, (126, 133)
# 4.80/100: flooding: 120/2499, 116.56, (114, 125)
# 5.76/100: flooding: 144/2499, 121.72, (109, 127)
# 6.72/100: flooding: 168/2499, 127.38, (112, 122)
# 7.68/100: flooding: 192/2499, 132.50, (133, 131)
# 8.64/100: flooding: 216/2499, 137.98, (131, 130)
# 9.60/100: flooding: 240/2499, 144.64, (129, 129)
# 10.56/100: flooding: 264/2499, 149.99, (125, 128)
# 11.52/100: flooding: 288/2499, 157.05, (125, 126)
# 12.48/100: flooding: 312/2499, 162.22, (125, 137)
# 13.45/100: flooding: 336/2499, 170.57, (130, 128)
# 14.41/100: flooding: 360/2499, 177.24, (120, 125)
# 15.37/100: flooding: 384/2499, 183.33, (128, 126)
# 16.33/100: flooding: 408/2499, 181.50, (123, 140)
# 17.29/100: flooding: 432/2499, 177.56, (128, 139)
# 18.25/100: flooding: 456/2499, 189.67, (123, 122)
# 19.21/100: flooding: 480/2499, 194.43, (122, 140)
# 20.17/100: flooding: 504/2499, 188.28, (119, 113)
# 21.13/100: flooding: 528/2499, 196.38, (121, 141)
# 22.09/100: flooding: 552/2499, 199.89, (122, 124)
# 23.05/100: flooding: 576/2499, 202.86, (110, 135)
# 24.01/100: flooding: 600/2499, 207.38, (122, 123)
# 24.97/100: flooding: 624/2499, 211.04, (110, 117)
# 25.93/100: flooding: 648/2499, 216.40, (131, 127)
# 26.89/100: flooding: 672/2499, 221.70, (121, 111)
# 27.85/100: flooding: 696/2499, 227.65, (108, 118)
# 28.81/100: flooding: 720/2499, 232.73, (107, 133)
# 29.77/100: flooding: 744/2499, 227.39, (99, 134)
# 30.73/100: flooding: 768/2499, 236.16, (103, 132)
# 31.69/100: flooding: 792/2499, 241.84, (97, 136)
# 32.65/100: flooding: 816/2499, 248.91, (129, 140)
# 33.61/100: flooding: 840/2499, 254.50, (111, 141)
# 34.57/100: flooding: 864/2499, 259.06, (106, 126)
# 35.53/100: flooding: 888/2499, 267.62, (136, 127)
# 36.49/100: flooding: 912/2499, 277.82, (134, 125)
# 37.45/100: flooding: 936/2499, 285.21, (98, 131)
# 92.20/100: flooding: 2304/2499, 2688.32, (129, 161)
# 93.16/100: flooding: 2328/2499, 2767.98, (93, 98)
# 94.12/100: flooding: 2352/2499, 2875.80, (131, 161)
# 95.08/100: flooding: 2376/2499, 2941.91, (135, 113)
# 96.04/100: flooding: 2400/2499, 3061.22, (100, 108)
# 97.00/100: flooding: 2424/2499, 3343.34, (91, 90)
# 97.96/100: flooding: 2448/2499, 3654.81, (98, 107)
# 98.92/100: flooding: 2472/2499, 4041.66, (149, 110)
# 99.88/100: flooding: 2496/2499, 4982.55, (96, 107)

# %%
imshow(ma.masked_array(clust.umat_cont, clust.mask), interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb40098c>

# %% [markdown]
# ## Computing clusters

# %%
clust.getclusters()
# Out:
# /usr/lib/pymodules/python2.7/numpy/ma/core.py:3785: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# (array([[19, 19, 19, ..., 15, 15, 19],
#        [19, 19, 21, ..., 15, 15, 15],
#        [19, 21, 20, ..., 15, 15, 15],
#        ...,
#        [ 2,  4,  7, ..., 22, 22, 22],
#        [ 4,  4,  7, ..., 22, 22, 22],
#        [ 4,  4,  7, ...,  9, 18, 19]]),
#  array([[ 0,  0,  0, ..., 15,  0,  0],
#        [19,  0,  0, ..., 15, 15,  0],
#        [ 0,  0,  0, ..., 15, 15,  0],
#        ...,
#        [ 0,  0,  0, ..., 22, 22, 22],
#        [ 0,  0,  0, ...,  0,  0,  0],
#        [ 4,  0,  0, ...,  0,  0,  0]]))

# %%
clust.plotclusters()

# %% [markdown]
# ## Which structures are in each clusters?

# %%
nframes = clust.labels.size
clusters = []
for i in range(nframes):
    clusters.append([i, clust.labels[i]])
clusters = asarray(clusters)
clusters = clusters[clusters[:,1].argsort()]
savetxt('clusters', clusters, fmt='%d')

# %% [markdown]
# # Projecting data onto the SOM

# %% [markdown]
# ## The RMSD

# %% [markdown]
# ### Structural alignment

# %%
traj.struct.atoms['coord'] = traj.struct.atoms['coord'] - traj.struct.atoms['coord'].mean(axis=0)

# %%
traj.align(templatestruct=(traj.struct.atoms['coord']).flatten())

# %%
i,j = traj.array.shape
print (i,j)
# Out:
# (9249, 168)

# %%
traj.array = traj.array.reshape((i, j/3, 3))
traj.array.shape
# Out:
# (9249, 56, 3)

# %% [markdown]
# ### Computing the RMSD

# %%
rmsds = sqrt((( traj.array - traj.struct.atoms['coord']*numpy.ones_like(traj.array) )**2).sum(axis=2)).mean(axis=1)

# %%
histo = hist(rmsds, 100, range=[0,5])

# %% [markdown]
# ### Projecting the RMSD onto the SOM

# %%
def project(data):
    pmap = zeros((X,Y))
    for c,e in enumerate(bmus):
        i,j = e
        pmap[i,j]+=data[c]
    pmap = pmap / density
    pmap = clust.flood(pmap, clust.x_offset, clust.y_offset, clust.mask)[0]
    return pmap
rmsdmap = project(rmsds)
# Out:
# -c:6: RuntimeWarning: invalid value encountered in divide

# %%
clust.plotclusters(color='k', matrix=rmsdmap, cmap=cm.PRGn, vmax=2.)

# %%
mu_rmsd = []
std_rmsd = []
clustid = unique(clust.labels)
for e in clustid:
    clustrmsd = rmsds[nonzero(clust.labels == e)[0]]
    mu = clustrmsd.mean()
    mu_rmsd.append(mu)
    std = clustrmsd.std()
    std_rmsd.append(std)
    text(e, mu+std, clustrmsd.size, horizontalalignment='center')
bar(clustid, mu_rmsd, yerr=std_rmsd, align='center')
ylabel("rmsd in A")
xlabel("cluster id")
grid()

# %% [markdown]
# ### Saving clusters

# %%
for e in unique(clust.labels):
    save('clust_%d'%e, traj.array[clust.labels == e])
